# %%
{'Client ID': 'Syv7stn-Rd-mtrudAbRvuaqMUb_AgdSirVvOb9XofEnxQ4_oYlVzptzilTlFhbcq',
    'Client Secret':'A0fegVhhiemDPVDdDdtYkW-8j9GF-d6pFv4_-_sbuX7Hm3yOzqlPL-HRof0bzHYu9x-CaYc0ak9AMQ3ZIYt_Ig',
'Client Access Token': 'HIs4ia8HMYMSYsZVHrYSFdAhcum7gHC0ZWMPa5pXJOoQUhd86oe6maD-BkIcKrnz'


}

# %%
export GENIUS_CLIENT_ACCESS_TOKEN="HIs4ia8HMYMSYsZVHrYSFdAhcum7gHC0ZWMPa5pXJOoQUhd86oe6maD-BkIcKrnz"

# %% [markdown]
# ### Importing necessary modules and files

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from glob import glob
import string

# %%
# loading data

df = pd.read_csv('lyrics.csv')
billboard = pd.read_csv('billboards.csv')

# %%
#df = pd.read_csv('lyrics.csv')
# after looking at the first element of the lyrics column, I need to be remove all the spacing and annotations in 
# the csv database as well as the scraped lyrics, because its not consistent with the other elements in the lyrics album
df['song'] = df.song.str.replace('-', " ")
df['artist'] = df.artist.str.replace('-', " ")
df['lyrics'] = df.lyrics.str.replace('\n', ' ')
df.head()
# Out:
#    index             song  year           artist genre  \
# 0      0        ego remix  2009  beyonce knowles   Pop
# 1      1     then tell me  2009  beyonce knowles   Pop
# 2      2          honesty  2009  beyonce knowles   Pop
# 3      3  you are my rock  2009  beyonce knowles   Pop
# 4      4    black culture  2009  beyonce knowles   Pop
#
#                                               lyrics
# 0  Oh baby, how you doing? You know I'm gonna cut...
# 1  playin' everything so easy, it's like you seem...
# 2  If you search For tenderness It isn't hard to ...
# 3  Oh oh oh I, oh oh oh I [Verse 1:] If I wrote a...
# 4  Party the people, the people the party it's po...

# %%
# cool after I finish cleaning this dataset, i need to figure out how to find the lyrics for the songs from my
# previous project. let me load the dataset into this project repo first

billboard = pd.read_csv('billboards.csv')
billboard.Song = billboard.Song.str.replace('>', 'than')
billboard.Artist = billboard.Artist.str.replace(' x ', ', ')
billboard.drop('num_weeks', inplace = True, axis = 1)
# billboard.head(20)

billboard_dict = billboard.to_dict('records')
billboard_dict[:5]
# Out:
# [{'Artist': '2 Chainz', 'Song': '4 AM'},
#  {'Artist': '2 Chainz', 'Song': "It's A Vibe"},
#  {'Artist': '2 Chainz', 'Song': 'Proud'},
#  {'Artist': '2 Chainz, Gucci Mane, Quavo', 'Song': 'Good Drank'},
#  {'Artist': '2 Chainz, Drake', 'Song': 'Bigger than You'}]

# %% [markdown]
# ### Testing out the thought process to get to the final product

# %% [markdown]
# Notes:
#
# 1. punctuation like $ will be replaced by '-' in the url
#
# 1. multiple artists will be in the url, so maybe i need to get all of the artists from the spotify api? put in a try/except so that i can keep track of all the songs that didn't work and do that later for a smaller subset of songs

# %%
from nltk import sent_tokenize, word_tokenize


# grabbing the data from the url
artist = 'Tessa Violet'
artist_url = artist.lower().replace(' ', '-')

source_code = requests.get(f'https://genius.com/{artist_url}-crush-lyrics')
soup = BeautifulSoup(source_code.text, 'html5lib')
lyrics = soup.find('div', class_='lyrics').text.strip()

#cleaning

lyrics = lyrics.replace('\n', '. ')
sentences = sent_tokenize(lyrics)
cleaned = [sentence for sentence in sentences if ('bridge' not in sentence.lower()) and ('verse' not in sentence.lower()) and ('chorus' not in sentence.lower()) and len(sentence) >1]

data = [artist, song, cleaned]
key =['artist', 'song', 'lyrics']
song_dict = dict(zip(key, data))
print(song_dict)

# %%
artist = 'Kanye West'
artist_url = artist.replace(' ', '-')

song = 'All of the Lights'
song_url = song.replace(' ', '-')


source_code = requests.get(f'https://genius.com/{artist_url}-{song_url}-lyrics')
soup = BeautifulSoup(source_code.text, 'html5lib')
lyrics = soup.find('div', class_='lyrics').text.strip()

#cleaning

lyrics = lyrics.replace('\n', '. ')
sentences = sent_tokenize(lyrics)
cleaned = [sentence for sentence in sentences if 
           ('produced' not in sentence.lower()) and
           ('intro' not in sentence.lower()) and
           ('outro' not in sentence.lower()) and
           ('bridge' not in sentence.lower()) and 
           ('verse' not in sentence.lower()) and 
           ('chorus' not in sentence.lower()) and len(sentence) >1]
cleaned

#it would be nice to all of this in a dictionary that i can just put into an array and then turn into a pd dataframe

data = [artist, song, cleaned]
key =['artist', 'song', 'lyrics']
song_dict = dict(zip(key, data))
# print(song_dict) #yay it worked
# please note it takes like a second for one song...

# %%
# https://genius.com/2-chainz-bigger-than-you-lyrics
    
source_code = requests.get('https://genius.com/2-chainz-bigger-than-you-lyrics')
soup = BeautifulSoup(source_code.text, 'html5lib')
lyrics = soup.find('div', class_='lyrics').text.strip()
print((lyrics))

# %%
billboard_dict

# %%
# i need to building a function that takes the billboard songs and just scrapes for songs!

def scrape_genius(artist, song):
    
    #artist = 'Kanye West'
    artist = artist.replace("'", '')
    song = song.replace("'", '')
    artist_url = artist.replace(' ', '-')
    #artist_url = artist.replace(',-', '-')
    #artist_url = artist.replace(',', '')

    #song = 'All of the Lights'
    song_url = song.replace(' ', '-')

    url = f'https://genius.com/{artist_url}-{song_url}-lyrics'
    # print(url)
    source_code = requests.get(url)
    soup = BeautifulSoup(source_code.text, 'html5lib')
    lyrics = soup.find('div', class_='lyrics').text.strip()

    #cleaning

    lyrics = lyrics.replace('\n', '. ')
    sentences = sent_tokenize(lyrics)
    cleaned = [sentence for sentence in sentences if 
               ('produced' not in sentence.lower()) and
               ('intro' not in sentence.lower()) and
               ('outro' not in sentence.lower()) and
               ('bridge' not in sentence.lower()) and 
               ('verse' not in sentence.lower()) and 
               ('chorus' not in sentence.lower()) and len(sentence) >1]
    cleaned

    #it would be nice to all of this in a dictionary that i can just put into an array and then turn into a pd dataframe

    data = [artist, song, cleaned]
    key =['artist', 'song', 'lyrics']
    song_dict = dict(zip(key, data))
    return song_dict

# %%
len(billboard_dict)
# Out:
# 828

# %% [markdown]
# ### Finally Scraping

# %%
smaller = billboard_dict[:20]

lyrics = []
missing = []
for record in smaller:
    song = record['Song']
    artist = record['Artist']
    artist = artist.replace(', ', ' ')
    artist = artist.replace('.', '')
    song = song.replace('.', '')
    #print(artist, song)
    # artist = record['Artist']
    try:
        lyrics.append(scrape_genius(artist, song))
    except:
        print(artist, song)
        missing.append(record)
        pass
    #print(lyrics)
    #print('done')

# %%
len(missing)
# Out:
# 20

# %%
len(lyrics)
# Out:
# 0

# %%
billboard_lyrics = pd.DataFrame(lyrics)

# %%
path_names = glob('second_round/*.pkl')
len(path_names)
# Out:
# 14406

# %%
song_df = pd.DataFrame()
missing = []

for path in path_names:
    try:
        
        song = pd.DataFrame(pd.read_pickle(str(path)))
        combined = song.groupby(['artist', 'song'])['lyrics'].apply(' '.join).reset_index()
        song_df = song_df.append(combined)
    except:
        missing.append(path)
        print(missing)
        #break
    
song_df
# Out:
#                         artist                                    song  \
# 0                 The Cascades                           The Last Leaf
# 0                  Keith Urban                       Youll Think Of Me
# 0                    BJ Thomas                                    Mama
# 0                 The Mixtures                           Pushbike Song
# 0               Greg Kihn Band                                Jeopardy
# 0                       Expose             I Wish The Phone Would Ring
# 0                   Carpenters                    I Need To Be In Love
# 0                 Soul II Soul                        A Dreams A Dream
# 0                    Vitamin Z                           Burning Flame
# 0               Herbie Hancock                               Chameleon
# 0                        Queen                    Tie Your Mother Down
# 0                  Rod Stewart                             Lost In You
# 0                The Shirelles                               Mama Said
# 0                Billy Preston                   I Wrote A Simple Song
# 0       George Baker Selection                                Dear Ann
# 0          The Everly Brothers               Dont Ask Me To Be Friends
# 0           Black Oak Arkansas                               Jim Dandy
# 0                David Cassidy                     Could It Be Forever
# 0                Lamont Dozier                         Fish Aint Bitin
# 0        New Kids On The Block                              Summertime
# 0                         Poco                          Nothin To Hide
# 0                 Brad Paisley                            Letter To Me
# 0             Peter And Gordon              To Know You Is To Love You
# 0               Connie Francis              In The Summer Of His Years
# 0                    LL Cool J                            How Im Comin
# 0          The Rooftop Singers                                 Tom Cat
# 0                 Natalie Cole                     When I Fall In Love
# 0                 Ginny Arnell                               Dumb Head
# 0                   El DeBarge                             Love Always
# 0               Hannah Montana                          Lets Get Crazy
# ..                         ...                                     ...
# 0                  David Gates                     Took The Last Train
# 0                Andy Williams                               Danny Boy
# 0              Three Dog Night                                     One
# 0               The Beach Boys                           Surfin Safari
# 0               Destinys Child                                 Emotion
# 0                      Dr Hook                              If Not You
# 0                       Winger                          Cant Get Enuff
# 0               Britney Spears                                   Lucky
# 0                   John Waite                             Missing You
# 0                      Pebbles                  Giving You The Benefit
# 0                Paulina Rubio                     Ni Una Sola Palabra
# 0                  Oleta Adams                                Get Here
# 0   YoungBoy Never Broke Again                           Outside Today
# 0               Mint Condition                          If You Love Me
# 0                 Tom Cochrane                             Washed Away
# 0                George Strait            Shell Leave You With A Smile
# 0                  Phil Vassar                         Six-Pack Summer
# 0                    Van Halen                                  Panama
# 0                 Pablo Cruise                      A Place In The Sun
# 0                Goo Goo Dolls                                    Iris
# 0                   Billy Idol                                LA Woman
# 0     Five Man Electrical Band                    Money Back Guarantee
# 0            Climax Blues Band                    Couldnt Get It Right
# 0                      Journey              Ill Be Alright Without You
# 0                 Taylor Dayne                            Dont Rush Me
# 0                      Gallery                  Big City Miss Ruth Ann
# 0                  Shane Minor                      Slave To The Habit
# 0                  Ringo Starr                          Wrack My Brain
# 0            Billy Edd Wheeler  Ode To The Little Brown Shack Out Back
# 0           The Rolling Stones                       Jumpin Jack Flash
#
#                                                lyrics
# 0   The last leaf clings to the bough. Just one le...
# 0   I woke up early this morning around 4am. With ...
# 0   Who's the one who tied you shoe when you were ...
# 0   Riding along my pushbike honey. When I noticed...
# 0   Oh Oh Oh Oh. Where were you when I needed you?...
# 0   More than ever you're on my mind. Being lonely...
# 0   The hardest thing I've ever done. Is keep beli...
# 0   I can see, i can see, i can see, i can see. I ...
# 0   Walking out tonight in the street lights I can...
# 0                                      [Instrumental]
# 0   Oooh yeah. Get your party gown. Get your pigta...
# 0   Hey baby. You've been on my mind tonight. I'm ...
# 0   Mama said there'll be days like this. There'll...
# 0   I wrote a simple song. With simple words and h...
# 0   Ann, oh, my dear Ann. You hit me in my face ag...
# 0   After all we've been. To one another. How can ...
# 0   Jim Dandy to the rescue!. Jim Dandy to the res...
# 0   Could it be forever. Or is my mind just rambli...
# 0   I'm out here fighting, hungry. The fish ain't ...
# 0   Jones Beach, 1988. Come on. Do you remember or...
# 0   Cryin' doesn't ease the pain. When the fire is...
# 0   If I could write a letter to me. And send it b...
# 0   Why can't you see?. Oh, how blind can you be?....
# 0   A young man rode with his head held high. Unde...
# 0   ("I'm comin'"). ("I'm comin'"). ("I'm comin'")...
# 0   Spoken:. I've got an old Tom Cat. And when he ...
# 0   And the moment I can feel that. You feel that ...
# 0   Dumb head (dumb head). I'm a stupid little gir...
# 0   I got a secret for you. Can't believe myself. ...
# 0   Life is just a party, so come as you are. Dres...
# ..                                                ...
# 0   Took the last train to St. Tropez. Had in mind...
# 0   Oh Danny Boy, the pipes, the pipes are calling...
# 0   One is the loneliest number that you'll ever d...
# 0   Let's go surfing now. Everybody's learning how...
# 0   U yeah..... . Its over and done. But the heart...
# 0   Who's gonna water my plants?. Who's gonna patc...
# 0   (Hey hey) I can't get enuff (hey hey!). (Hey h...
# 0   This is a story about a girl named Lucky. Earl...
# 0   Every time I think of you. I always catch my b...
# 0   G-G-Giving you, giving you. G-G-Giving you, gi...
# 0   Le está gritando y hace que no se entera. "Hey...
# 0   You can reach me by railway. You can reach me ...
# 0   I ain't going outside today. I ain't going out...
# 0   If you love me. Like you say you do. Won’t you...
# 0   We live out here in the desert. Where time sta...
# 0   At first she's going to come on strong. Like S...
# 0   Winter sure was cold and miserable. Cooped up,...
# 0   Jump back, what's that sound?. Here she comes,...
# 0   Well everybodys heart needs a holiday, some ti...
# 0   And I'd give up forever to touch you. Cause I ...
# 0   Well I met a little babe. An hour ago. Wonder ...
# 0   Well, I sat down in front of my TV set. And so...
# 0   Time was drifting. This rocker got to roll. So...
# 0   I've been thinking about the times. You walked...
# 0   Red roses, temptation. You make the most of a ...
# 0   You came here from the country. You left your ...
# 0   (Kostas/Toby Keith/Chuck Cannon). It ain't wro...
# 0   Wrack my brain, wrack my brain. Till my head's...
# 0   They passed an ordinance in the town. They sai...
# 0   One two!. I was born in a crossfire hurricane....
#
# [14405 rows x 3 columns]

# %%
missing = [path for path in path_names if 'Copy1' in path]

#print(missing[0])


missing_df = pd.DataFrame(pd.read_pickle(str(missing[0])))
song_df= song_df.append(missing_df)
pd.to_pickle(song_df, 'scraped_lyrics_816.pkl')

# %%
all_billboard_songs = (pd.DataFrame(pd.read_pickle('unique_songs.pkl')).drop('num_weeks', axis = 1)).rename(columns = {
    'Artist':'artist',
    'Song':'song'})

all_billboard_songs.artist = all_billboard_songs.artist.str.replace("'", '')
all_billboard_songs.song = all_billboard_songs.song.str.replace("'", '')
    
combined = all_billboard_songs.merge(song_df, how = 'left').drop_duplicates(['artist', 'song'])

combined.head(10)
# Out:
#                     artist                                               song  \
# 0         Rick Springfield                                       Jessies Girl
# 3               Air Supply                              The One That You Love
# 5            Joey Scarbury  Theme From "Greatest American Hero" (Believe I...
# 6             Kenny Rogers                                    I Dont Need You
# 9       The Oak Ridge Boys                                             Elvira
# 11     The Pointer Sisters                                          Slow Hand
# 12              Kim Carnes                                   Bette Davis Eyes
# 14  The Manhattan Transfer                             Boy From New York City
# 16             Marty Balin                                             Hearts
# 18            Juice Newton                                    Queen Of Hearts
#
#                                                lyrics
# 0   Jessie is a friend. Yeah I know he's been a go...
# 3   [Now the night has gone., Now the night has go...
# 5                                                 NaN
# 6   I don't need you. I don't need friendship. I d...
# 9   [Elvira, Elvira., My heart's on fire, for Elvi...
# 11                                                NaN
# 12  [Her hair is Harlow gold., Her lips sweet surp...
# 14  [Ooo wah, ooo wah cool, cool kitty., Tell us a...
# 16  [Is everything all right?., I just called to s...
# 18  [Midnight, and I'm a-waiting on the twelve-oh-...

# %%
missing_lyrics_df = combined.loc[combined.lyrics.isnull()]
missing_lyrics_df.head(10)
# Out:
#                          artist  \
# 5                 Joey Scarbury
# 11          The Pointer Sisters
# 20        Daryl Hall John Oates
# 21              The Moody Blues
# 22                Ronnie Milsap
# 23   Diana Ross & Lionel Richie
# 29                   Commodores
# 32   Stanley Clarke/George Duke
# 45                  Stars On 45
# 48               Greg Kihn Band
#
#                                                  song lyrics
# 5   Theme From "Greatest American Hero" (Believe I...    NaN
# 11                                          Slow Hand    NaN
# 20                                 You Make My Dreams    NaN
# 21                                       Gemini Dream    NaN
# 22                         (Theres) No Gettin Over Me    NaN
# 23                                       Endless Love    NaN
# 29                             Lady (You Bring Me Up)    NaN
# 32                                         Sweet Baby    NaN
# 45                                             Medley    NaN
# 48              The Breakup Song (They Dont Write Em)    NaN

# %%
translator = str.maketrans('', '', string.punctuation)

missing_lyrics_df.song = missing_lyrics_df.song.str.translate(translator)
missing_lyrics_df.artist = missing_lyrics_df.artist.str.translate(translator)
missing_lyrics_df = missing_lyrics_df.drop('lyrics', axis =1)
# Out:
# /Users/jennwon/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
missing_dict = missing_lyrics_df.to_dict(orient = 'records')
missing_dict[:5]
missing_list = []

for track in missing_dict[::-1]:
    #print(song)
    artist = track['artist']
    song = track['song']
    try:
        results = scrape_genius(artist, song)
        artist_file = artist.replace(' ', '_')
        song_file = song.replace(' ', '_')
        print(artist_file, song_file)
        break
        pd.to_pickle(results, f'second_round/{artist_file}_{song_file}.pkl')
        print(results)
    except:
        print('sad')
        missing_list.append(track)
    #print(results)
    #print(artist, song)
    #break
# Out:
# https://genius.com/Zedd-Maren-Morris-The-Middle-lyrics
# sad
# https://genius.com/Zay-Hilfigerrr-Juju-On-That-Beat-TZ-Anthem-lyrics
# sad
# https://genius.com/XXXTENTACION-Infinity-888-lyrics
# sad
# https://genius.com/XXXTENTACION-Fk-Love-lyrics
# sad
# https://genius.com/Tim-McGraw-The-Rest-Of-Our-Life-lyrics
# sad
# https://genius.com/Tim-McGraw-Speak-To-A-Girl-lyrics
# sad
# https://genius.com/The-Weeknd-Pray-For-Me-lyrics
# sad
# https://genius.com/Sofia-Carson-Cameron-Boyce-Booboo-Stewart-Chillin-Like-A-Villain-lyrics
# sad
# https://genius.com/ScHoolboy-Q-2-Chainz-X-lyrics
# sad
# https://genius.com/Quavo-Takeoff-Too-Hotty-lyrics
# sad
# https://genius.com/Quavo-Ice-Tray-lyrics
# sad
# https://genius.com/Pusha-T-What-Would-Meek-Do-lyrics
# sad
# https://genius.com/Playboi-Carti-Wokeuplikethis-lyrics
# sad
# https://genius.com/Offset-Ric-Flair-Drip-lyrics
# sad
# https://genius.com/Offset-Nightmare-lyrics
# sad
# https://genius.com/Noah-Cyrus-Make-Me-Cry-lyrics
# sad
# https://genius.com/Nicki-Minaj-Drake-No-Frauds-lyrics
# sad
# https://genius.com/NERD-Lemon-lyrics
# sad
# https://genius.com/Migos-Nicki-Minaj-MotorSport-lyrics
# sad
# https://genius.com/Migos-Danger-lyrics
# sad
# https://genius.com/Migos-BBO-Bad-Bitches-Only-lyrics
# sad
# https://genius.com/Meek-Mill-Fk-That-Check-Up-lyrics
# sad
# https://genius.com/Machine-Gun-Kelly-X-Ambassadors-Home-lyrics
# sad
# https://genius.com/Luis-Fonsi-Echame-La-Culpa-lyrics
# sad
# https://genius.com/LinManuel-Miranda-Found--Tonight-lyrics
# sad
# https://genius.com/Lil-Yachty-Boom-lyrics
# sad
# https://genius.com/Lil-Baby-Yes-Indeed-lyrics
# sad
# https://genius.com/Liam-Payne-For-You-Fifty-Shades-Freed-lyrics
# sad
# https://genius.com/Kygo-Born-To-Be-Yours-lyrics
# sad
# https://genius.com/Khalid-Ty-Dolla-ign-OTW-lyrics
# sad
# https://genius.com/Khalid-Love-Lies-lyrics
# sad
# https://genius.com/Kendrick-Lamar-XXX-lyrics
# sad
# https://genius.com/Kendrick-Lamar-Loyalty-lyrics
# sad
# https://genius.com/Kendrick-Lamar-Love-lyrics
# sad
# https://genius.com/Kendrick-Lamar-Big-Shot-lyrics
# sad
# https://genius.com/Jay-Rock-Kendrick-Lamar-Future-Kings-Dead-lyrics
# sad
# https://genius.com/J-Cole-The-Cut-Off-lyrics
# sad
# https://genius.com/J-Cole-Friends-lyrics
# sad
# https://genius.com/Hugh-Jackman-Keala-Settle-Zac-Efron-Zendaya-The-Greatest-Show-lyrics
# sad
# https://genius.com/Hailee-Steinfeld-Let-Me-Go-lyrics
# sad
# https://genius.com/GEazy-Him--I-lyrics
# sad
# https://genius.com/Future-Three-lyrics
# sad
# https://genius.com/Future-Patek-Water-lyrics
# sad
# https://genius.com/Future-No-Cap-lyrics
# sad
# https://genius.com/Future-All-Da-Smoke-lyrics
# sad
# https://genius.com/Florida-Georgia-Line-God-Your-Mama-And-Me-lyrics

# %%
def scrape_genius(artist, song):
    artist_url = artist.replace(' ', '-')
    song_url = song.replace(' ', '-')

    url = f'https://genius.com/{artist_url}-{song_url}-lyrics'
    print(url)
    source_code = requests.get(url)
    soup = BeautifulSoup(source_code.text, 'html5lib')
    lyrics = soup.find('div', class_='lyrics').text.strip()

    #cleaning

    lyrics = lyrics.replace('\n', '. ')
    sentences = sent_tokenize(lyrics)
    cleaned = [sentence for sentence in sentences if 
               ('produced' not in sentence.lower()) and
               ('intro' not in sentence.lower()) and
               ('outro' not in sentence.lower()) and
               ('bridge' not in sentence.lower()) and 
               ('verse' not in sentence.lower()) and 
               ('chorus' not in sentence.lower()) and len(sentence) >1]

    #it would be nice to all of this in a dictionary that i can just put into an array and then turn into a pd dataframe

    data = [artist, song, cleaned]
    key =['artist', 'song', 'lyrics']
    song_dict = dict(zip(key, data))
    return song_dict
